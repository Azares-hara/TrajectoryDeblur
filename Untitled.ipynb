# %%
if torch.cuda.is_available():
    print("GPU is available.")
    print(f"Current GPU: {torch.cuda.get_device_name(0)}")
else:
    print("GPU is not available. Using CPU.")
# Out:
# GPU is available.
# Current GPU: NVIDIA A100 80GB PCIe

# %%
import sys
import os 
project_root = os.path.abspath(".")
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
# !nvidia-smi
# Out:
# Mon Apr 13 16:37:03 2026
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.183.06             Driver Version: 535.183.06   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100 80GB PCIe          Off | 00000000:CA:00.0 Off |                    0 |
# | N/A   57C    P0             156W / 300W |  72521MiB / 81920MiB |     97%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A   1605736      C   ...aconda3/envs/uav_seg/bin/python3.10    10644MiB |
# |    0   N/A  N/A   2175775      C   ...nda3/envs/computervision/bin/python    22212MiB |
# |    0   N/A  N/A   2215330      C   ...8/anaconda3/envs/deblur2/bin/python      414MiB |
# |    0   N/A  N/A   2276681      C   ...nda3/envs/computervision/bin/python     3816MiB |
# |    0   N/A  N/A   2973877      C   ...anaconda3/envs/urbantwin/bin/python      728MiB |
# |    0   N/A  N/A   3799202      C   ...12/anaconda3/envs/deblur/bin/python    13490MiB |
# |    0   N/A  N/A   3892360      C   python                                     2042MiB |
# +---------------------------------------------------------------------------------------+

# %%
# !ps -p 1528486 -o pid,cmd
# Out:
#     PID CMD
# 1528486 /home/p25cs012/anaconda3/envs/deblur/bin/python -m ipykernel_launcher -f

# %%
# !nvidia-smi --query-compute-apps=pid,process_name,used_memory --format=csv,noheader,nounits
# Out:
# 1894164, /home/p24cs006/anaconda3/envs/flare/bin/python, 18868
# 2185082, /home/t24cs017/anaconda3/envs/surveillance/bin/python, 3396
# 2134518, /home/t24cs017/anaconda3/envs/surveillance/bin/python, 3396
# 2133660, /home/t24cs017/anaconda3/envs/surveillance/bin/python, 1100
# 2774247, /home/p24cs010/anaconda3/envs/uav_seg/bin/python3.10, 10644
# 2882703, /home/t24cs017/anaconda3/envs/surveillance/bin/python, 3742
# 3017688, /home/p25cs012/anaconda3/envs/deblur/bin/python, 13814
# 3040123, python, 19112
# 3156304, python, 3708
# 3040025, /home/dsr/anaconda3/envs/urbantwin/bin/python, 1774
